# %%
#Q1
import datetime as dt
def greet(name):
    current_time = dt.datetime.now()
    print(f"Hello, {name}! The current time is {current_time}.")
greet("Khizra")
# Out:
# Hello, Khizra! The current time is 2025-12-02 10:00:04.621348.

# %%
#Q2
def calculate_average(a, b, c):
    average = ((a+ b+ c)/3)
    print(average)
calculate_average(6, 7, 8)
# Out:
# 7.0

# %%
#Q3
def calculate_discount(price, discount_percentage=10):
    discount_amount = ((price*discount_percentage)/100)
    print(discount_amount)
calculate_discount(2000)
# Out:
# 200.0

# %%
#Q4
def print_info(name,age,city):
    print(f"Name: ",name)
    print(f"Age: ",age)
    print(f"City: ",city)
print_info("Khizra", 19,"Lahore")
# Out:
# Name:  Khizra
# Age:  19
# City:  Lahore

# %%
#Q5
def find_max(*args):
    if not args:
        return none
    return max(args)
result = find_max(10,20,55,78,95)
print(f"The maximum value is: {result}")
# Out:
# The maximum value is: 95
